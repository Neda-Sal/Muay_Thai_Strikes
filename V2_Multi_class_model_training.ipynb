# %% [markdown]
# # Train yolov3 model on 6 classes: kick, punch, elbow, knee, clinch, stance
#
# The following code was originally run in google colab and was adapted from [this](https://www.youtube.com/watch?v=_FNfRtXEbr4&amp%3Bab_channel=Pysource) resource.

# %% [markdown]
# Don't forget to check that the class labels are correct in the corresponding .txt files

# %%
#check if NVIDIA GPU is enabled
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
else:
    print(gpu_info)
# Out:
# Mon Nov 30 08:11:40 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#connect google colab with google drive.
from google.colab import drive
drive.mount('/content/gdrive')

# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# %% [markdown]
# ## Clone the Darknet repo

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 14518 (delta 0), reused 3 (delta 0), pack-reused 14500
# Receiving objects: 100% (14518/14518), 13.23 MiB | 3.92 MiB/s, done.
# Resolving deltas: 100% (9861/9861), done.

# %% [markdown]
# ## Compile Darknet using Nvidia GPU

# %%
#change makefile to have GPU and OPENCV enabled
# %cd darknet

# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ./src/image_opencv.cpp:1130:10: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#           if (iteration_old != 0){
#           ^~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1424:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ./src/image_opencv.cpp:1400:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#      int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1404:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#      int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1408:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#      int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1411:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#      int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#          ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:580:0:
# ./src/httplib.h:129:0: warning: "INVALID_SOCKET" redefined
#  #define INVALID_SOCKET (-1)
#
# ./src/http_stream.cpp:73:0: note: this is the location of the previous definition
#  #define INVALID_SOCKET -1
#
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:249:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:507:113: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#                  sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#                                                                                                                  ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:863:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
#                          ~~^~~~~~~~~~
# ./src/http_stream.cpp:871:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#                           ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:890:31: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#                          ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:926:28: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#          ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2038:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2037:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1045:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#      while (c = *str++)
#             ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:224:20: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum <anonymous>’ [-Wenum-compare]
#          if (status != CUDNN_STATUS_SUCCESS)
#                     ^~
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:276:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                       ~~^
#                                       %Ilu
#              size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#              ~~~~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:276:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                               ~~^
#                                                               %Ilu
# ./src/dark_cuda.c:276:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                                                 ~~^
#                                                                                 %Ilu
# ./src/dark_cuda.c:286:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                                     ~^
#                                     %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:307:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                                           ~^
#                                           %ld
# ./src/dark_cuda.c:322:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                                                                ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                                %ld
# ./src/dark_cuda.c:328:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                               %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1341:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^~~~~~~~~
# ./src/blas.c: In function ‘find_sim’:
# ./src/blas.c:597:59: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                           ~^
#                                                           %ld
# ./src/blas.c:597:67: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                   ~^
#                                                                   %ld
# ./src/blas.c:597:75: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                           ~^
#                                                                           %ld
# ./src/blas.c: In function ‘find_P_constrastive’:
# ./src/blas.c:611:68: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                    ~^
#                                                                    %ld
# ./src/blas.c:611:76: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                            ~^
#                                                                            %ld
# ./src/blas.c:611:84: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                                    ~^
#                                                                                    %ld
# ./src/blas.c: In function ‘P_constrastive_f’:
# ./src/blas.c:651:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:651:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# ./src/blas.c: In function ‘P_constrastive’:
# ./src/blas.c:785:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:785:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘make_contrastive_layer’:
# ./src/softmax_layer.c:203:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 9 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#      fprintf(stderr, "contrastive %4d x%4d x%4d x emb_size %4d x batch: %4d  classes = %4d, step = %4d \n", w, h, l.n, l.embedding_size, batch, l.classes, step);
#                                                                                                    ~~^
#                                                                                                    %4ld
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:244:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#                      float max_truth = 0;
#                            ^~~~~~~~~
# ./src/softmax_layer.c:423:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#              printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#                                                                       ~^
#                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1297:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:1090:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:647:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1679:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:428:29: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#          classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#          ~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:0:
# /usr/include/stdlib.h:541:14: note: in a call to allocation function ‘calloc’ declared here
#  extern void *calloc (size_t __nmemb, size_t __size)
#               ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘print_cocos’:
# ./src/detector.c:484:29: warning: format not a string literal and no format arguments [-Wformat-security]
#                  fprintf(fp, buff);
#                              ^~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:577:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:698:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^~~~
# ./src/detector.c:696:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1329:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1328:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1863:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#              float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#                    ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:208:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#      if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#                                                    ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1287:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^~~~~~~~~~~
# ./src/classifier.c:1287:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:100:16: warning: unused variable ‘prediction’ [-Wunused-variable]
#          float *prediction = network_predict(net, X);
#                 ^~~~~~~~~~
# ./src/demo.c:98:15: warning: unused variable ‘l’ [-Wunused-variable]
#          layer l = net.layers[net.n - 1];
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:59:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^~~~~
# ./src/region_layer.c:58:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:68:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:75:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:106:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:115:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘process_batch’:
# ./src/yolo_layer.c:412:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#                      int best_match_t = 0;
#                          ^~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:880:15: warning: unused variable ‘avg_iou_loss’ [-Wunused-variable]
#          float avg_iou_loss = 0;
#                ^~~~~~~~~~~~
# ./src/yolo_layer.c:693:11: warning: unused variable ‘avg_anyobj’ [-Wunused-variable]
#      float avg_anyobj = 0;
#            ^~~~~~~~~~
# ./src/yolo_layer.c:692:11: warning: unused variable ‘avg_obj’ [-Wunused-variable]
#      float avg_obj = 0;
#            ^~~~~~~
# ./src/yolo_layer.c:691:11: warning: unused variable ‘avg_cat’ [-Wunused-variable]
#      float avg_cat = 0;
#            ^~~~~~~
# ./src/yolo_layer.c:690:11: warning: unused variable ‘recall75’ [-Wunused-variable]
#      float recall75 = 0;
#            ^~~~~~~~
# ./src/yolo_layer.c:689:11: warning: unused variable ‘recall’ [-Wunused-variable]
#      float recall = 0;
#            ^~~~~~
# ./src/yolo_layer.c:688:11: warning: unused variable ‘tot_ciou_loss’ [-Wunused-variable]
#      float tot_ciou_loss = 0;
#            ^~~~~~~~~~~~~
# ./src/yolo_layer.c:687:11: warning: unused variable ‘tot_diou_loss’ [-Wunused-variable]
#      float tot_diou_loss = 0;
#            ^~~~~~~~~~~~~
# ./src/yolo_layer.c:686:11: warning: unused variable ‘tot_giou_loss’ [-Wunused-variable]
#      float tot_giou_loss = 0;
#            ^~~~~~~~~~~~~
# ./src/yolo_layer.c:685:11: warning: unused variable ‘tot_iou_loss’ [-Wunused-variable]
#      float tot_iou_loss = 0;
#            ^~~~~~~~~~~~
# ./src/yolo_layer.c:684:11: warning: unused variable ‘tot_ciou’ [-Wunused-variable]
#      float tot_ciou = 0;
#            ^~~~~~~~
# ./src/yolo_layer.c:683:11: warning: unused variable ‘tot_diou’ [-Wunused-variable]
#      float tot_diou = 0;
#            ^~~~~~~~
# ./src/yolo_layer.c:682:11: warning: unused variable ‘tot_giou’ [-Wunused-variable]
#      float tot_giou = 0;
#            ^~~~~~~~
# ./src/yolo_layer.c:654:12: warning: unused variable ‘n’ [-Wunused-variable]
#      int b, n;
#             ^
# ...
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:110:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:119:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# ./src/convolutional_kernels.cu: In function ‘void backward_convolutional_layer_gpu(convolutional_layer, network_state)’:
# ./src/convolutional_kernels.cu:853:40: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (*state.net.max_output16_size < l.nweights) {
#                  ~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:1130:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^~~~
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu: In function ‘float train_network_datum_gpu(network, float*, float*)’:
# ./src/network_kernels.cu:364:7: warning: variable ‘l’ set but not used [-Wunused-but-set-variable]
#          layer l = net.layers[net.n - 1];
#        ^
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %% [markdown]
# ## Configure Darknet network for training YOLO V3

# %%
#make a copy of the confiuration file to make changes to
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %% [markdown]
# ## Make the following changes:
# - batch = 64
#
# - subdivisions = 16 *(if 16 gives a CUDA out of memory error, can go up to 32)*
#
# - max_batches = 2000*(num_classes) = 12000
#
# - steps = (80%)\*max_batches, (90%)*max_batches = 9600, 10800
#
# - classes = 6 *(on lines 610, 696, 783)*
#
# - filters = (num_classes + 5)\*3 = 33 *(on lines 603, 689, 776)*

# %%
#change the configuration settings
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches=500200/max_batches=12000/' cfg/yolov3_training.cfg
# !sed -i 's/steps=400000,450000/steps=9600,10800/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=6@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=6@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=6@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=33@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=33@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=33@' cfg/yolov3_training.cfg

# %%
# !echo "kick\npunch\nknee\nelbow\nclinch\nstance" > data/obj.names
# !echo -e 'classes= 6\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3_multiclass_v2' > data/obj.data
# !mkdir data/obj

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-11-30 08:24:18--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   288KB/s    in 8m 47s
#
# 2020-11-30 08:33:07 (301 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !unzip /mydrive/yolov3_multiclass_v2/images.zip -d data/obj
# Out:
# Archive:  /mydrive/yolov3_multiclass_v2/images.zip
#   inflating: data/obj/2clinch1.png
#   inflating: data/obj/__MACOSX/._2clinch1.png
#   inflating: data/obj/2clinch1.txt
#   inflating: data/obj/2clinch2.png
#   inflating: data/obj/__MACOSX/._2clinch2.png
#   inflating: data/obj/2clinch2.txt
#   inflating: data/obj/2clinch3.png
#   inflating: data/obj/__MACOSX/._2clinch3.png
#   inflating: data/obj/2clinch3.txt
#   inflating: data/obj/2clinch4.png
#   inflating: data/obj/__MACOSX/._2clinch4.png
#   inflating: data/obj/2clinch4.txt
#   inflating: data/obj/2clinch5.png
#   inflating: data/obj/__MACOSX/._2clinch5.png
#   inflating: data/obj/clinch35.txt
#   inflating: data/obj/clinch36.png
#   inflating: data/obj/__MACOSX/._clinch36.png
#   inflating: data/obj/clinch36.txt
#   inflating: data/obj/clinch37.png
#   inflating: data/obj/__MACOSX/._clinch37.png
#   inflating: data/obj/clinch37.txt
#   inflating: data/obj/clinch38.png
#   inflating: data/obj/__MACOSX/._clinch38.png
#   inflating: data/obj/clinch38.txt
#   inflating: data/obj/elbow_0c7cf05c6108085280115a3eb7e8d5e9.jpg
#   inflating: data/obj/__MACOSX/._elbow_0c7cf05c6108085280115a3eb7e8d5e9.jpg
#   inflating: data/obj/elbow_0c7cf05c6108085280115a3eb7e8d5e9.txt
#   inflating: data/obj/elbow_21092_367408206680533_1199672835_n.jpg
#   inflating: data/obj/__MACOSX/._elbow_21092_367408206680533_1199672835_n.jpg
#   inflating: data/obj/elbow_21092_367408206680533_1199672835_n.txt
#   inflating: data/obj/__MACOSX/._elbow_21092_367408206680533_1199672835_n.txt
#   inflating: data/obj/elbow_44512e0b9937cd10bbe4afc3c44afc03.jpg
#   inflating: data/obj/__MACOSX/._elbow_44512e0b9937cd10bbe4afc3c44afc03.jpg
#   inflating: data/obj/elbow_44512e0b9937cd10bbe4afc3c44afc03.txt
#   inflating: data/obj/elbow_944779295b12cf9d9eeac7cefdd0f5f8.jpg
#   inflating: data/obj/__MACOSX/._elbow_944779295b12cf9d9eeac7cefdd0f5f8.jpg
#   inflating: data/obj/elbow_944779295b12cf9d9eeac7cefdd0f5f8.txt
#   inflating: data/obj/elbow_Ajh2eiURGqwdIi1hEhAp_file.jpg
#   inflating: data/obj/__MACOSX/._elbow_Ajh2eiURGqwdIi1hEhAp_file.jpg
#   inflating: data/obj/elbow_Ajh2eiURGqwdIi1hEhAp_file.txt
#   inflating: data/obj/elbow_buakaw-banchamek-gaetan-dambo.jpg
#   inflating: data/obj/__MACOSX/._elbow_buakaw-banchamek-gaetan-dambo.jpg
#   inflating: data/obj/elbow_buakaw-banchamek-gaetan-dambo.txt
#   inflating: data/obj/elbow_DOb544NXUAAJJG8.jpg
#   inflating: data/obj/__MACOSX/._elbow_DOb544NXUAAJJG8.jpg
#   inflating: data/obj/elbow_DOb544NXUAAJJG8.txt
#   inflating: data/obj/elbow_download.jpg
#   inflating: data/obj/__MACOSX/._elbow_download.jpg
#   inflating: data/obj/elbow_download.txt
#   inflating: data/obj/elbow_image (1).jpeg
#   inflating: data/obj/__MACOSX/._elbow_image (1).jpeg
#   inflating: data/obj/elbow_image (1).txt
#   inflating: data/obj/elbow_image (2).jpeg
#   inflating: data/obj/__MACOSX/._elbow_image (2).jpeg
#   inflating: data/obj/elbow_image (2).txt
#   inflating: data/obj/elbow_image (4).jpeg
#   inflating: data/obj/__MACOSX/._elbow_image (4).jpeg
#   inflating: data/obj/elbow_image (4).txt
#   inflating: data/obj/elbow_image (5).jpeg
#   inflating: data/obj/__MACOSX/._elbow_image (5).jpeg
#   inflating: data/obj/elbow_image (5).txt
#   inflating: data/obj/elbow_image (8).jpeg
#   inflating: data/obj/__MACOSX/._elbow_image (8).jpeg
#   inflating: data/obj/elbow_image (8).txt
#   inflating: data/obj/elbow_image (10).jpeg
#   inflating: data/obj/__MACOSX/._elbow_image (10).jpeg
#   inflating: data/obj/elbow_image (10).txt
#   inflating: data/obj/elbow_image (14).jpeg
#   inflating: data/obj/__MACOSX/._elbow_image (14).jpeg
#   inflating: data/obj/elbow_image (14).txt
#   inflating: data/obj/elbow_image (15).jpeg
#   inflating: data/obj/__MACOSX/._elbow_image (15).jpeg
#   inflating: data/obj/elbow_image (15).txt
#   inflating: data/obj/elbow_image (17).jpeg
#   inflating: data/obj/__MACOSX/._elbow_image (17).jpeg
#   inflating: data/obj/elbow_image (17).txt
#   inflating: data/obj/elbow_image (18).jpeg
#   inflating: data/obj/__MACOSX/._elbow_image (18).jpeg
#   inflating: data/obj/elbow_image (18).txt
#   inflating: data/obj/elbow_image.jpeg
#   inflating: data/obj/__MACOSX/._elbow_image.jpeg
#   inflating: data/obj/elbow_image.txt
#   inflating: data/obj/elbow_images (1)3.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)3.jpg
#   inflating: data/obj/elbow_images (1)3.txt
#   inflating: data/obj/elbow_images (1)ad.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)ad.jpg
#   inflating: data/obj/elbow_images (1)ad.txt
#   inflating: data/obj/elbow_images (1)adgfg.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)adgfg.jpg
#   inflating: data/obj/elbow_images (1)adgfg.txt
#   inflating: data/obj/elbow_images (1)agdfgfhfy.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)agdfgfhfy.jpg
#   inflating: data/obj/elbow_images (1)agdfgfhfy.txt
#   inflating: data/obj/elbow_images (1)ahfhhfhfb.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)ahfhhfhfb.jpg
#   inflating: data/obj/elbow_images (1)ahfhhfhfb.txt
#   inflating: data/obj/elbow_images (1)ajfdg.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)ajfdg.jpg
#   inflating: data/obj/elbow_images (1)ajfdg.txt
#   inflating: data/obj/elbow_images (1)ajfg.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)ajfg.jpg
#   inflating: data/obj/elbow_images (1)ajfg.txt
#   inflating: data/obj/elbow_images (1)d.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)d.jpg
#   inflating: data/obj/elbow_images (1)d.txt
#   inflating: data/obj/elbow_images (1)dsjfh.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)dsjfh.jpg
#   inflating: data/obj/elbow_images (1)dsjfh.txt
#   inflating: data/obj/elbow_images (1)hg.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)hg.jpg
#   inflating: data/obj/elbow_images (1)hg.txt
#   inflating: data/obj/elbow_images (1)j.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)j.jpg
#   inflating: data/obj/elbow_images (1)j.txt
#   inflating: data/obj/elbow_images (1)jdhf.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)jdhf.jpg
#   inflating: data/obj/elbow_images (1)jdhf.txt
#   inflating: data/obj/elbow_images (1)sdjhf.jpg
#   inflating: data/obj/__MACOSX/._elbow_images (1)sdjhf.jpg
#   inflating: data/obj/elbow_images (1)sdjhf.txt
#   inflating: data/obj/elbow_images (2).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (2).jpeg
#   inflating: data/obj/elbow_images (2).txt
#   inflating: data/obj/elbow_images (6).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (6).jpeg
#   inflating: data/obj/elbow_images (6).txt
#   inflating: data/obj/elbow_images (7).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (7).jpeg
#   inflating: data/obj/elbow_images (7).txt
#   inflating: data/obj/elbow_images (8).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (8).jpeg
#   inflating: data/obj/elbow_images (8).txt
#   inflating: data/obj/elbow_images (9).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (9).jpeg
#   inflating: data/obj/elbow_images (9).txt
#   inflating: data/obj/elbow_images (12).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (12).jpeg
#   inflating: data/obj/elbow_images (12).txt
#   inflating: data/obj/elbow_images (13).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (13).jpeg
#   inflating: data/obj/elbow_images (13).txt
#   inflating: data/obj/elbow_images (14).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (14).jpeg
#   inflating: data/obj/elbow_images (14).txt
#   inflating: data/obj/elbow_images (15).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (15).jpeg
#   inflating: data/obj/elbow_images (15).txt
#   inflating: data/obj/elbow_images (16).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (16).jpeg
#   inflating: data/obj/elbow_images (16).txt
#   inflating: data/obj/elbow_images (17).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (17).jpeg
#   inflating: data/obj/elbow_images (17).txt
#   inflating: data/obj/elbow_images (19).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (19).jpeg
#   inflating: data/obj/elbow_images (19).txt
#   inflating: data/obj/elbow_images (20).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (20).jpeg
#   inflating: data/obj/elbow_images (20).txt
#   inflating: data/obj/elbow_images (21).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (21).jpeg
#   inflating: data/obj/elbow_images (21).txt
#   inflating: data/obj/elbow_images (22).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (22).jpeg
#   inflating: data/obj/elbow_images (22).txt
#   inflating: data/obj/elbow_images (23).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (23).jpeg
#   inflating: data/obj/elbow_images (23).txt
#   inflating: data/obj/elbow_images (24).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (24).jpeg
#   inflating: data/obj/elbow_images (24).txt
#   inflating: data/obj/elbow_images (27).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (27).jpeg
#   inflating: data/obj/elbow_images (27).txt
#   inflating: data/obj/elbow_images (31).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (31).jpeg
#   inflating: data/obj/elbow_images (31).txt
#   inflating: data/obj/elbow_images (36).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (36).jpeg
#   inflating: data/obj/elbow_images (36).txt
#   inflating: data/obj/elbow_images (37).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (37).jpeg
#   inflating: data/obj/elbow_images (37).txt
#   inflating: data/obj/elbow_images (38).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (38).jpeg
#   inflating: data/obj/elbow_images (38).txt
#   inflating: data/obj/elbow_images (40).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (40).jpeg
#   inflating: data/obj/elbow_images (40).txt
#   inflating: data/obj/elbow_images (41).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (41).jpeg
#   inflating: data/obj/elbow_images (41).txt
#   inflating: data/obj/elbow_images (49).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (49).jpeg
#   inflating: data/obj/elbow_images (49).txt
#   inflating: data/obj/elbow_images (50).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (50).jpeg
#   inflating: data/obj/elbow_images (50).txt
#   inflating: data/obj/elbow_images (52).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (52).jpeg
#   inflating: data/obj/elbow_images (52).txt
#   inflating: data/obj/elbow_images (53).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (53).jpeg
#   inflating: data/obj/elbow_images (53).txt
#   inflating: data/obj/elbow_images (57).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (57).jpeg
#   inflating: data/obj/elbow_images (57).txt
#   inflating: data/obj/elbow_images (61).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (61).jpeg
#   inflating: data/obj/elbow_images (61).txt
#   inflating: data/obj/elbow_images (62).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (62).jpeg
#   inflating: data/obj/elbow_images (62).txt
#   inflating: data/obj/elbow_images (69).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (69).jpeg
#   inflating: data/obj/elbow_images (69).txt
#   inflating: data/obj/__MACOSX/._elbow_images (69).txt
#   inflating: data/obj/elbow_images (71).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (71).jpeg
#   inflating: data/obj/elbow_images (71).txt
#   inflating: data/obj/elbow_images (73).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (73).jpeg
#   inflating: data/obj/elbow_images (73).txt
#   inflating: data/obj/elbow_images (75).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (75).jpeg
#   inflating: data/obj/elbow_images (75).txt
#   inflating: data/obj/elbow_images (76).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (76).jpeg
#   inflating: data/obj/elbow_images (76).txt
#   inflating: data/obj/elbow_images (78).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (78).jpeg
#   inflating: data/obj/elbow_images (78).txt
#   inflating: data/obj/elbow_images (79).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (79).jpeg
#   inflating: data/obj/elbow_images (79).txt
#   inflating: data/obj/elbow_images (80).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (80).jpeg
#   inflating: data/obj/elbow_images (80).txt
#   inflating: data/obj/elbow_images (81).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (81).jpeg
#   inflating: data/obj/elbow_images (81).txt
#   inflating: data/obj/elbow_images (82).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (82).jpeg
#   inflating: data/obj/elbow_images (82).txt
#   inflating: data/obj/elbow_images (83).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (83).jpeg
#   inflating: data/obj/elbow_images (83).txt
#   inflating: data/obj/elbow_images (89).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (89).jpeg
#   inflating: data/obj/elbow_images (89).txt
#   inflating: data/obj/elbow_images (90).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (90).jpeg
#   inflating: data/obj/elbow_images (90).txt
#   inflating: data/obj/elbow_images (93).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (93).jpeg
#   inflating: data/obj/elbow_images (93).txt
#   inflating: data/obj/elbow_images (94).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (94).jpeg
#   inflating: data/obj/elbow_images (94).txt
#   inflating: data/obj/elbow_images (96).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (96).jpeg
#   inflating: data/obj/elbow_images (96).txt
#   inflating: data/obj/elbow_images (97).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (97).jpeg
#   inflating: data/obj/elbow_images (97).txt
#   inflating: data/obj/elbow_images (98).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (98).jpeg
#   inflating: data/obj/elbow_images (98).txt
#   inflating: data/obj/elbow_images (101).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (101).jpeg
#   inflating: data/obj/elbow_images (101).txt
#   inflating: data/obj/elbow_images (106).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (106).jpeg
#   inflating: data/obj/elbow_images (106).txt
#   inflating: data/obj/elbow_images (108).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (108).jpeg
#   inflating: data/obj/elbow_images (108).txt
#   inflating: data/obj/elbow_images (109).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (109).jpeg
#   inflating: data/obj/elbow_images (109).txt
#   inflating: data/obj/elbow_images (110).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (110).jpeg
#   inflating: data/obj/elbow_images (110).txt
#   inflating: data/obj/elbow_images (114).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (114).jpeg
#   inflating: data/obj/elbow_images (114).txt
#   inflating: data/obj/elbow_images (115).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (115).jpeg
#   inflating: data/obj/elbow_images (115).txt
#   inflating: data/obj/elbow_images (116).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (116).jpeg
#   inflating: data/obj/elbow_images (116).txt
#   inflating: data/obj/elbow_images (117).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (117).jpeg
#   inflating: data/obj/elbow_images (117).txt
#   inflating: data/obj/elbow_images (118).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (118).jpeg
#   inflating: data/obj/elbow_images (118).txt
#   inflating: data/obj/elbow_images (119).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (119).jpeg
#   inflating: data/obj/elbow_images (119).txt
#   inflating: data/obj/elbow_images (120).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (120).jpeg
#   inflating: data/obj/elbow_images (120).txt
#   inflating: data/obj/elbow_images (121).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (121).jpeg
#   inflating: data/obj/elbow_images (121).txt
#   inflating: data/obj/elbow_images (122).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (122).jpeg
#   inflating: data/obj/elbow_images (122).txt
#   inflating: data/obj/elbow_images (125).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (125).jpeg
#   inflating: data/obj/elbow_images (125).txt
#   inflating: data/obj/elbow_images (127).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (127).jpeg
#   inflating: data/obj/elbow_images (127).txt
#   inflating: data/obj/elbow_images (129).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (129).jpeg
#   inflating: data/obj/elbow_images (129).txt
#   inflating: data/obj/elbow_images (135).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (135).jpeg
#   inflating: data/obj/elbow_images (135).txt
#   inflating: data/obj/elbow_images (141).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (141).jpeg
#   inflating: data/obj/elbow_images (141).txt
#   inflating: data/obj/elbow_images (142).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (142).jpeg
#   inflating: data/obj/elbow_images (142).txt
#   inflating: data/obj/elbow_images (143).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (143).jpeg
#   inflating: data/obj/elbow_images (143).txt
#   inflating: data/obj/elbow_images (147).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (147).jpeg
#   inflating: data/obj/elbow_images (147).txt
#   inflating: data/obj/elbow_images (151).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (151).jpeg
#   inflating: data/obj/elbow_images (151).txt
#   inflating: data/obj/elbow_images (154).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (154).jpeg
#   inflating: data/obj/elbow_images (154).txt
#   inflating: data/obj/elbow_images (158).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (158).jpeg
#   inflating: data/obj/elbow_images (158).txt
#   inflating: data/obj/elbow_images (161).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (161).jpeg
#   inflating: data/obj/elbow_images (161).txt
#   inflating: data/obj/elbow_images (162).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (162).jpeg
#   inflating: data/obj/elbow_images (162).txt
#   inflating: data/obj/elbow_images (169).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (169).jpeg
#   inflating: data/obj/elbow_images (169).txt
#   inflating: data/obj/elbow_images (172).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (172).jpeg
#   inflating: data/obj/elbow_images (172).txt
#   inflating: data/obj/elbow_images (176).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (176).jpeg
#   inflating: data/obj/elbow_images (176).txt
#   inflating: data/obj/elbow_images (177).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (177).jpeg
#   inflating: data/obj/elbow_images (177).txt
#   inflating: data/obj/elbow_images (179) copy.jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (179) copy.jpeg
#   inflating: data/obj/elbow_images (179) copy.txt
#   inflating: data/obj/elbow_images (179).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (179).jpeg
#   inflating: data/obj/elbow_images (179).txt
#   inflating: data/obj/elbow_images (181).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (181).jpeg
#   inflating: data/obj/elbow_images (181).txt
#   inflating: data/obj/elbow_images (182).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (182).jpeg
#   inflating: data/obj/elbow_images (182).txt
#   inflating: data/obj/elbow_images (183).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (183).jpeg
#   inflating: data/obj/elbow_images (183).txt
#   inflating: data/obj/elbow_images (188).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (188).jpeg
#   inflating: data/obj/elbow_images (188).txt
#   inflating: data/obj/elbow_images (190).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (190).jpeg
#   inflating: data/obj/elbow_images (190).txt
#   inflating: data/obj/elbow_images (191).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (191).jpeg
#   inflating: data/obj/elbow_images (191).txt
#   inflating: data/obj/elbow_images (195).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (195).jpeg
#   inflating: data/obj/elbow_images (195).txt
#   inflating: data/obj/elbow_images (196).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (196).jpeg
#   inflating: data/obj/elbow_images (196).txt
#   inflating: data/obj/elbow_images (200).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (200).jpeg
#   inflating: data/obj/elbow_images (200).txt
#   inflating: data/obj/elbow_images (202).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (202).jpeg
#   inflating: data/obj/elbow_images (202).txt
#   inflating: data/obj/elbow_images (203).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (203).jpeg
#   inflating: data/obj/elbow_images (203).txt
#   inflating: data/obj/elbow_images (208).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (208).jpeg
#   inflating: data/obj/elbow_images (208).txt
#   inflating: data/obj/elbow_images (209).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (209).jpeg
#   inflating: data/obj/elbow_images (209).txt
#   inflating: data/obj/elbow_images (211).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (211).jpeg
#   inflating: data/obj/elbow_images (211).txt
#   inflating: data/obj/elbow_images (216).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (216).jpeg
#   inflating: data/obj/elbow_images (216).txt
#   inflating: data/obj/elbow_images (217).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (217).jpeg
#   inflating: data/obj/elbow_images (217).txt
#   inflating: data/obj/elbow_images (218).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (218).jpeg
#   inflating: data/obj/elbow_images (218).txt
#   inflating: data/obj/elbow_images (219).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (219).jpeg
#   inflating: data/obj/elbow_images (219).txt
#   inflating: data/obj/elbow_images (222).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (222).jpeg
#   inflating: data/obj/elbow_images (222).txt
#   inflating: data/obj/elbow_images (223).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (223).jpeg
#   inflating: data/obj/elbow_images (223).txt
#   inflating: data/obj/elbow_images (228).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (228).jpeg
#   inflating: data/obj/elbow_images (228).txt
#   inflating: data/obj/elbow_images (232).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (232).jpeg
#   inflating: data/obj/elbow_images (232).txt
#   inflating: data/obj/elbow_images (233).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (233).jpeg
#   inflating: data/obj/elbow_images (233).txt
#   inflating: data/obj/elbow_images (234).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (234).jpeg
#   inflating: data/obj/elbow_images (234).txt
#   inflating: data/obj/elbow_images (235).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (235).jpeg
#   inflating: data/obj/elbow_images (235).txt
#   inflating: data/obj/elbow_images (236).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (236).jpeg
#   inflating: data/obj/elbow_images (236).txt
#   inflating: data/obj/elbow_images (238).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (238).jpeg
#   inflating: data/obj/elbow_images (238).txt
#   inflating: data/obj/elbow_images (239).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (239).jpeg
#   inflating: data/obj/elbow_images (239).txt
#   inflating: data/obj/elbow_images (245).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (245).jpeg
#   inflating: data/obj/elbow_images (245).txt
#   inflating: data/obj/elbow_images (255).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (255).jpeg
#   inflating: data/obj/elbow_images (255).txt
#   inflating: data/obj/elbow_images (260).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (260).jpeg
#   inflating: data/obj/elbow_images (260).txt
#   inflating: data/obj/elbow_images (266).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (266).jpeg
#   inflating: data/obj/elbow_images (266).txt
#   inflating: data/obj/elbow_images (270).jpeg
#   inflating: data/obj/__MACOSX/._elbow_images (270).jpeg
#   inflating: data/obj/elbow_images (270).txt
#   inflating: data/obj/elbow_images elb.jpeg
#   inflating: data/obj/__MACOSX/._elbow_images elb.jpeg
#   inflating: data/obj/elbow_images elb.txt
#   inflating: data/obj/elbow_images.jpeg
#   inflating: data/obj/__MACOSX/._elbow_images.jpeg
#   inflating: data/obj/elbow_images.txt
#   inflating: data/obj/elbow_Lethwei-vs.jpg
#   inflating: data/obj/__MACOSX/._elbow_Lethwei-vs.jpg
#   inflating: data/obj/elbow_Lethwei-vs.txt
#   inflating: data/obj/elbow_main-qimg-2a8ccf2fab0809f3216afa833b2d75d6.jpg
#   inflating: data/obj/__MACOSX/._elbow_main-qimg-2a8ccf2fab0809f3216afa833b2d75d6.jpg
#   inflating: data/obj/elbow_main-qimg-2a8ccf2fab0809f3216afa833b2d75d6.txt
#   inflating: data/obj/elbow_main-qimg-5ef3b34213e52fd9cf51cf81117a86ae.jpg
#   inflating: data/obj/__MACOSX/._elbow_main-qimg-5ef3b34213e52fd9cf51cf81117a86ae.jpg
#   inflating: data/obj/elbow_main-qimg-5ef3b34213e52fd9cf51cf81117a86ae.txt
#   inflating: data/obj/elbow_main-qimg-9daca34bf95040196b059c7f512fa85f.jpg
#   inflating: data/obj/__MACOSX/._elbow_main-qimg-9daca34bf95040196b059c7f512fa85f.jpg
#   inflating: data/obj/elbow_main-qimg-9daca34bf95040196b059c7f512fa85f.txt
#   inflating: data/obj/elbow_max-muay-thai.jpg
#   inflating: data/obj/__MACOSX/._elbow_max-muay-thai.jpg
#   inflating: data/obj/elbow_max-muay-thai.txt
#   inflating: data/obj/elbow_nse216-b88472491z.120150731222942000gg2b72dj.10.jpg
#   inflating: data/obj/__MACOSX/._elbow_nse216-b88472491z.120150731222942000gg2b72dj.10.jpg
#   inflating: data/obj/elbow_nse216-b88472491z.120150731222942000gg2b72dj.10.txt
#   inflating: data/obj/elbow_slashing-elbow-728x640 (1).jpg
#   inflating: data/obj/__MACOSX/._elbow_slashing-elbow-728x640 (1).jpg
#   inflating: data/obj/elbow_slashing-elbow-728x640 (1).txt
#   inflating: data/obj/elbow_slashing-elbow-728x640.jpg
#   inflating: data/obj/__MACOSX/._elbow_slashing-elbow-728x640.jpg
#   inflating: data/obj/elbow_slashing-elbow-728x640.txt
#   inflating: data/obj/elbow_unnamed_1.jpg
#   inflating: data/obj/__MACOSX/._elbow_unnamed_1.jpg
#   inflating: data/obj/elbow_unnamed_1.txt
#   inflating: data/obj/elbow_zimages (18).jpeg
#   inflating: data/obj/__MACOSX/._elbow_zimages (18).jpeg
#   inflating: data/obj/elbow_zimages (18).txt
#   inflating: data/obj/elbow_zimages (32).jpeg
#   inflating: data/obj/__MACOSX/._elbow_zimages (32).jpeg
#   inflating: data/obj/elbow_zimages (32).txt
#   inflating: data/obj/elbow2_2elbow1.png
#   inflating: data/obj/__MACOSX/._elbow2_2elbow1.png
#   inflating: data/obj/elbow2_2elbow1.txt
#   inflating: data/obj/elbow2_2elbow2.png
#   inflating: data/obj/__MACOSX/._elbow2_2elbow2.png
#   inflating: data/obj/elbow2_2elbow2.txt
#   inflating: data/obj/elbow2_2elbow3.png
#   inflating: data/obj/__MACOSX/._elbow2_2elbow3.png
#   inflating: data/obj/elbow2_2elbow3.txt
#   inflating: data/obj/elbow2_2elbow4.png
#   inflating: data/obj/__MACOSX/._elbow2_2elbow4.png
#   inflating: data/obj/elbow2_2elbow4.txt
#   inflating: data/obj/elbow2_2elbow5.png
#   inflating: data/obj/__MACOSX/._elbow2_2elbow5.png
#   inflating: data/obj/elbow2_2elbow5.txt
#   inflating: data/obj/elbow2_2elbow6.png
#   inflating: data/obj/__MACOSX/._elbow2_2elbow6.png
#   inflating: data/obj/elbow2_2elbow6.txt
#   inflating: data/obj/elbow2_elbow_knee1.png
#   inflating: data/obj/__MACOSX/._elbow2_elbow_knee1.png
#   inflating: data/obj/elbow2_elbow_knee1.txt
#   inflating: data/obj/ha_knee_clinch1.png
#   inflating: data/obj/__MACOSX/._ha_knee_clinch1.png
#   inflating: data/obj/ha_knee_clinch1.txt
#   inflating: data/obj/ha_knee_clinch2.png
#   inflating: data/obj/__MACOSX/._ha_knee_clinch2.png
#   inflating: data/obj/ha_knee_clinch2.txt
#   inflating: data/obj/ha_knee_clinch3.png
#   inflating: data/obj/__MACOSX/._ha_knee_clinch3.png
#   inflating: data/obj/ha_knee_clinch3.txt
#   inflating: data/obj/ha_knee_clinch4.png
#   inflating: data/obj/__MACOSX/._ha_knee_clinch4.png
#   inflating: data/obj/ha_knee_clinch4.txt
#   inflating: data/obj/ha_knee_clinch5.png
#   inflating: data/obj/__MACOSX/._ha_knee_clinch5.png
#   inflating: data/obj/ha_knee_clinch5.txt
#   inflating: data/obj/ha_knee_clinch6.png
#   inflating: data/obj/__MACOSX/._ha_knee_clinch6.png
#   inflating: data/obj/ha_knee_clinch6.txt
#   inflating: data/obj/ha_knee_clinch7.png
#   inflating: data/obj/__MACOSX/._ha_knee_clinch7.png
#   inflating: data/obj/ha_knee_clinch7.txt
#   inflating: data/obj/ha_knee_clinch8.png
#   inflating: data/obj/__MACOSX/._ha_knee_clinch8.png
#   inflating: data/obj/ha_knee_clinch8.txt
#   inflating: data/obj/ha_knee_clinch9.png
#   inflating: data/obj/__MACOSX/._ha_knee_clinch9.png
#   inflating: data/obj/ha_knee_clinch9.txt
#   inflating: data/obj/ha_knee_clinch10.png
#   inflating: data/obj/__MACOSX/._ha_knee_clinch10.png
#   inflating: data/obj/ha_knee_clinch10.txt
#   inflating: data/obj/ha_knee_clinch11.png
#   inflating: data/obj/__MACOSX/._ha_knee_clinch11.png
#   inflating: data/obj/ha_knee_clinch11.txt
#   inflating: data/obj/image (1).jpeg
#   inflating: data/obj/__MACOSX/._image (1).jpeg
#   inflating: data/obj/image (1).txt
#   inflating: data/obj/image (2).jpeg
#   inflating: data/obj/__MACOSX/._image (2).jpeg
#   inflating: data/obj/image (2).txt
#   inflating: data/obj/image (3).jpeg
#   inflating: data/obj/__MACOSX/._image (3).jpeg
#   inflating: data/obj/image (3).txt
#   inflating: data/obj/image (4).jpeg
#   inflating: data/obj/__MACOSX/._image (4).jpeg
#   inflating: data/obj/image (4).txt
#   inflating: data/obj/image (6).jpeg
#   inflating: data/obj/__MACOSX/._image (6).jpeg
#   inflating: data/obj/image (6).txt
#   inflating: data/obj/image (8).jpeg
#   inflating: data/obj/__MACOSX/._image (8).jpeg
#   inflating: data/obj/image (8).txt
#   inflating: data/obj/image (9).jpeg
#   inflating: data/obj/__MACOSX/._image (9).jpeg
#   inflating: data/obj/image (9).txt
#   inflating: data/obj/image (13).jpeg
#   inflating: data/obj/__MACOSX/._image (13).jpeg
#   inflating: data/obj/image (13).txt
#   inflating: data/obj/image (14).jpeg
#   inflating: data/obj/__MACOSX/._image (14).jpeg
#   inflating: data/obj/image (14).txt
#   inflating: data/obj/image (16).jpeg
#   inflating: data/obj/__MACOSX/._image (16).jpeg
#   inflating: data/obj/image (16).txt
#   inflating: data/obj/image (17).jpeg
#   inflating: data/obj/__MACOSX/._image (17).jpeg
#   inflating: data/obj/image (17).txt
#   inflating: data/obj/image.jpeg
#   inflating: data/obj/__MACOSX/._image.jpeg
#   inflating: data/obj/image.txt
#   inflating: data/obj/images (1).jpeg
#   inflating: data/obj/__MACOSX/._images (1).jpeg
#   inflating: data/obj/images (1).txt
#   inflating: data/obj/images (2).jpeg
#   inflating: data/obj/__MACOSX/._images (2).jpeg
#   inflating: data/obj/images (2).txt
#   inflating: data/obj/images (3).jpeg
#   inflating: data/obj/__MACOSX/._images (3).jpeg
#   inflating: data/obj/images (3).txt
#   inflating: data/obj/images (4).jpeg
#   inflating: data/obj/__MACOSX/._images (4).jpeg
#   inflating: data/obj/images (4).txt
#   inflating: data/obj/images (5).jpeg
#   inflating: data/obj/__MACOSX/._images (5).jpeg
#   inflating: data/obj/images (5).txt
#   inflating: data/obj/images (7).jpeg
#   inflating: data/obj/__MACOSX/._images (7).jpeg
#   inflating: data/obj/images (7).txt
#   inflating: data/obj/images (9).jpeg
#   inflating: data/obj/__MACOSX/._images (9).jpeg
#   inflating: data/obj/images (9).txt
#   inflating: data/obj/images (10).jpeg
#   inflating: data/obj/__MACOSX/._images (10).jpeg
#   inflating: data/obj/images (10).txt
#   inflating: data/obj/images (11).jpeg
#   inflating: data/obj/__MACOSX/._images (11).jpeg
#   inflating: data/obj/images (11).txt
#   inflating: data/obj/images (12).jpeg
#   inflating: data/obj/__MACOSX/._images (12).jpeg
#   inflating: data/obj/images (12).txt
#   inflating: data/obj/images (13).jpeg
#   inflating: data/obj/__MACOSX/._images (13).jpeg
#   inflating: data/obj/images (13).txt
#   inflating: data/obj/images (14).jpeg
#   inflating: data/obj/__MACOSX/._images (14).jpeg
#   inflating: data/obj/images (14).txt
#   inflating: data/obj/images (16).jpeg
#   inflating: data/obj/__MACOSX/._images (16).jpeg
#   inflating: data/obj/images (16).txt
#   inflating: data/obj/images (17).jpeg
#   inflating: data/obj/__MACOSX/._images (17).jpeg
#   inflating: data/obj/images (17).txt
#   inflating: data/obj/images (19).jpeg
#   inflating: data/obj/__MACOSX/._images (19).jpeg
#   inflating: data/obj/images (19).txt
#   inflating: data/obj/images (24).jpeg
#   inflating: data/obj/__MACOSX/._images (24).jpeg
#   inflating: data/obj/images (24).txt
#   inflating: data/obj/images (25).jpeg
#   inflating: data/obj/__MACOSX/._images (25).jpeg
#   inflating: data/obj/images (25).txt
#   inflating: data/obj/images (26).jpeg
#   inflating: data/obj/__MACOSX/._images (26).jpeg
#   inflating: data/obj/images (26).txt
#   inflating: data/obj/images (27).jpeg
#   inflating: data/obj/__MACOSX/._images (27).jpeg
#   inflating: data/obj/images (27).txt
#   inflating: data/obj/images (31).jpeg
#   inflating: data/obj/__MACOSX/._images (31).jpeg
#   inflating: data/obj/images (31).txt
#   inflating: data/obj/images (33).jpeg
#   inflating: data/obj/__MACOSX/._images (33).jpeg
#   inflating: data/obj/images (33).txt
#   inflating: data/obj/images (35).jpeg
#   inflating: data/obj/__MACOSX/._images (35).jpeg
#   inflating: data/obj/images (35).txt
#   inflating: data/obj/images (36).jpeg
#   inflating: data/obj/__MACOSX/._images (36).jpeg
#   inflating: data/obj/images (36).txt
#   inflating: data/obj/images (37).jpeg
#   inflating: data/obj/__MACOSX/._images (37).jpeg
#   inflating: data/obj/images (37).txt
#   inflating: data/obj/images (38).jpeg
#   inflating: data/obj/__MACOSX/._images (38).jpeg
#   inflating: data/obj/images (38).txt
#   inflating: data/obj/images (40).jpeg
#   inflating: data/obj/__MACOSX/._images (40).jpeg
#   inflating: data/obj/images (40).txt
#   inflating: data/obj/images (41).jpeg
#   inflating: data/obj/__MACOSX/._images (41).jpeg
#   inflating: data/obj/images (41).txt
#   inflating: data/obj/images (42).jpeg
#   inflating: data/obj/__MACOSX/._images (42).jpeg
#   inflating: data/obj/images (42).txt
#   inflating: data/obj/images (43).jpeg
#   inflating: data/obj/__MACOSX/._images (43).jpeg
#   inflating: data/obj/images (43).txt
#   inflating: data/obj/images (47).jpeg
#   inflating: data/obj/__MACOSX/._images (47).jpeg
#   inflating: data/obj/images (47).txt
#   inflating: data/obj/images (48).jpeg
#   inflating: data/obj/__MACOSX/._images (48).jpeg
#   inflating: data/obj/images (48).txt
#   inflating: data/obj/images (51).jpeg
#   inflating: data/obj/__MACOSX/._images (51).jpeg
#   inflating: data/obj/images (51).txt
#   inflating: data/obj/images (52).jpeg
#   inflating: data/obj/__MACOSX/._images (52).jpeg
#   inflating: data/obj/images (52).txt
#   inflating: data/obj/images (55).jpeg
#   inflating: data/obj/__MACOSX/._images (55).jpeg
#   inflating: data/obj/images (55).txt
#   inflating: data/obj/images (57).jpeg
#   inflating: data/obj/__MACOSX/._images (57).jpeg
#   inflating: data/obj/images (57).txt
#   inflating: data/obj/images (59).jpeg
#   inflating: data/obj/__MACOSX/._images (59).jpeg
#   inflating: data/obj/images (59).txt
#   inflating: data/obj/images (60).jpeg
#   inflating: data/obj/__MACOSX/._images (60).jpeg
#   inflating: data/obj/images (60).txt
#   inflating: data/obj/images (62).jpeg
#   inflating: data/obj/__MACOSX/._images (62).jpeg
#   inflating: data/obj/images (62).txt
#   inflating: data/obj/images (66).jpeg
#   inflating: data/obj/__MACOSX/._images (66).jpeg
#   inflating: data/obj/images (66).txt
#   inflating: data/obj/images (69).jpeg
#   inflating: data/obj/__MACOSX/._images (69).jpeg
#   inflating: data/obj/images (69).txt
#   inflating: data/obj/images (70).jpeg
#   inflating: data/obj/__MACOSX/._images (70).jpeg
#   inflating: data/obj/images (70).txt
#   inflating: data/obj/images (73).jpeg
#   inflating: data/obj/__MACOSX/._images (73).jpeg
#   inflating: data/obj/images (73).txt
#   inflating: data/obj/images (75).jpeg
#   inflating: data/obj/__MACOSX/._images (75).jpeg
#   inflating: data/obj/images (75).txt
#   inflating: data/obj/images (77).jpeg
#   inflating: data/obj/__MACOSX/._images (77).jpeg
#   inflating: data/obj/images (77).txt
#   inflating: data/obj/images (78).jpeg
#   inflating: data/obj/__MACOSX/._images (78).jpeg
#   inflating: data/obj/images (78).txt
#   inflating: data/obj/images (79).jpeg
#   inflating: data/obj/__MACOSX/._images (79).jpeg
#   inflating: data/obj/images (79).txt
#   inflating: data/obj/images (81).jpeg
#   inflating: data/obj/__MACOSX/._images (81).jpeg
#   inflating: data/obj/images (81).txt
#   inflating: data/obj/images (86).jpeg
#   inflating: data/obj/__MACOSX/._images (86).jpeg
#   inflating: data/obj/images (86).txt
#   inflating: data/obj/images (87).jpeg
#   inflating: data/obj/__MACOSX/._images (87).jpeg
#   inflating: data/obj/images (87).txt
#   inflating: data/obj/images (88).jpeg
#   inflating: data/obj/__MACOSX/._images (88).jpeg
#   inflating: data/obj/images (88).txt
#   inflating: data/obj/images (89).jpeg
#   inflating: data/obj/__MACOSX/._images (89).jpeg
#   inflating: data/obj/images (89).txt
#   inflating: data/obj/images (91).jpeg
#   inflating: data/obj/__MACOSX/._images (91).jpeg
#   inflating: data/obj/images (91).txt
#   inflating: data/obj/images (95).jpeg
#   inflating: data/obj/__MACOSX/._images (95).jpeg
#   inflating: data/obj/images (95).txt
#   inflating: data/obj/images (96).jpeg
#   inflating: data/obj/__MACOSX/._images (96).jpeg
#   inflating: data/obj/images (96).txt
#   inflating: data/obj/images (97).jpeg
#   inflating: data/obj/__MACOSX/._images (97).jpeg
#   inflating: data/obj/images (97).txt
#   inflating: data/obj/images (99).jpeg
#   inflating: data/obj/__MACOSX/._images (99).jpeg
#   inflating: data/obj/images (99).txt
#   inflating: data/obj/images (100).jpeg
#   inflating: data/obj/__MACOSX/._images (100).jpeg
#   inflating: data/obj/images (100).txt
#   inflating: data/obj/images (102).jpeg
#   inflating: data/obj/__MACOSX/._images (102).jpeg
#   inflating: data/obj/images (102).txt
#   inflating: data/obj/images (106).jpeg
#   inflating: data/obj/__MACOSX/._images (106).jpeg
#   inflating: data/obj/images (106).txt
#   inflating: data/obj/images (108).jpeg
#   inflating: data/obj/__MACOSX/._images (108).jpeg
#   inflating: data/obj/images (108).txt
#   inflating: data/obj/images (110).jpeg
#   inflating: data/obj/__MACOSX/._images (110).jpeg
#   inflating: data/obj/images (110).txt
#   inflating: data/obj/images (112).jpeg
#   inflating: data/obj/__MACOSX/._images (112).jpeg
#   inflating: data/obj/images (112).txt
#   inflating: data/obj/images (115).jpeg
#   inflating: data/obj/__MACOSX/._images (115).jpeg
#   inflating: data/obj/images (115).txt
#   inflating: data/obj/images (119).jpeg
#   inflating: data/obj/__MACOSX/._images (119).jpeg
#   inflating: data/obj/images (119).txt
#   inflating: data/obj/images (122).jpeg
#   inflating: data/obj/__MACOSX/._images (122).jpeg
#   inflating: data/obj/images (122).txt
#   inflating: data/obj/images (124).jpeg
#   inflating: data/obj/__MACOSX/._images (124).jpeg
#   inflating: data/obj/images (124).txt
#   inflating: data/obj/images (125).jpeg
#   inflating: data/obj/__MACOSX/._images (125).jpeg
#   inflating: data/obj/images (125).txt
#   inflating: data/obj/images (126).jpeg
#   inflating: data/obj/__MACOSX/._images (126).jpeg
#   inflating: data/obj/images (126).txt
#   inflating: data/obj/images (127).jpeg
#   inflating: data/obj/__MACOSX/._images (127).jpeg
#   inflating: data/obj/images (127).txt
#   inflating: data/obj/images (128) 1.27.19 AM.jpeg
#   inflating: data/obj/__MACOSX/._images (128) 1.27.19 AM.jpeg
#   inflating: data/obj/images (128) 1.27.19 AM.txt
#   inflating: data/obj/images (128).jpeg
#   inflating: data/obj/__MACOSX/._images (128).jpeg
#   inflating: data/obj/images (128).txt
#   inflating: data/obj/images (132).jpeg
#   inflating: data/obj/__MACOSX/._images (132).jpeg
#   inflating: data/obj/images (132).txt
#   inflating: data/obj/images (137).jpeg
#   inflating: data/obj/__MACOSX/._images (137).jpeg
#   inflating: data/obj/images (137).txt
#   inflating: data/obj/images (139).jpeg
#   inflating: data/obj/__MACOSX/._images (139).jpeg
#   inflating: data/obj/images (139).txt
#   inflating: data/obj/images (140).jpeg
#   inflating: data/obj/__MACOSX/._images (140).jpeg
#   inflating: data/obj/images (140).txt
#   inflating: data/obj/images (141).jpeg
#   inflating: data/obj/__MACOSX/._images (141).jpeg
#   inflating: data/obj/images (141).txt
#   inflating: data/obj/images (143).jpeg
#   inflating: data/obj/__MACOSX/._images (143).jpeg
#   inflating: data/obj/images (143).txt
#   inflating: data/obj/images (147).jpeg
#   inflating: data/obj/__MACOSX/._images (147).jpeg
#   inflating: data/obj/images (147).txt
#   inflating: data/obj/images (149).jpeg
#   inflating: data/obj/__MACOSX/._images (149).jpeg
#   inflating: data/obj/images (149).txt
#   inflating: data/obj/images (151).jpeg
#   inflating: data/obj/__MACOSX/._images (151).jpeg
#   inflating: data/obj/images (151).txt
#   inflating: data/obj/images (153).jpeg
#   inflating: data/obj/__MACOSX/._images (153).jpeg
#   inflating: data/obj/images (153).txt
#   inflating: data/obj/images (154).jpeg
#   inflating: data/obj/__MACOSX/._images (154).jpeg
#   inflating: data/obj/images (154).txt
#   inflating: data/obj/images (155).jpeg
#   inflating: data/obj/__MACOSX/._images (155).jpeg
#   inflating: data/obj/images (155).txt
#   inflating: data/obj/images (157).jpeg
#   inflating: data/obj/__MACOSX/._images (157).jpeg
#   inflating: data/obj/images (157).txt
#   inflating: data/obj/images (161).jpeg
#   inflating: data/obj/__MACOSX/._images (161).jpeg
#   inflating: data/obj/images (161).txt
#   inflating: data/obj/images (165).jpeg
#   inflating: data/obj/__MACOSX/._images (165).jpeg
#   inflating: data/obj/images (165).txt
#   inflating: data/obj/images (170).jpeg
#   inflating: data/obj/__MACOSX/._images (170).jpeg
# ...
#   inflating: data/obj/stance_2stance48.txt
#   inflating: data/obj/stance_2stance49.png
#   inflating: data/obj/__MACOSX/._stance_2stance49.png
#   inflating: data/obj/stance_2stance49.txt
#   inflating: data/obj/stance_2stance50.png
#   inflating: data/obj/__MACOSX/._stance_2stance50.png
#   inflating: data/obj/stance_2stance50.txt
#   inflating: data/obj/stance_2stance51.png
#   inflating: data/obj/__MACOSX/._stance_2stance51.png
#   inflating: data/obj/stance_2stance51.txt
#   inflating: data/obj/stance_2stance52.png
#   inflating: data/obj/__MACOSX/._stance_2stance52.png
#   inflating: data/obj/stance_2stance52.txt
#   inflating: data/obj/stance_2stance53.png
#   inflating: data/obj/__MACOSX/._stance_2stance53.png
#   inflating: data/obj/stance_2stance53.txt
#   inflating: data/obj/stance_image (1).jpeg
#   inflating: data/obj/__MACOSX/._stance_image (1).jpeg
#   inflating: data/obj/stance_image (1).txt
#   inflating: data/obj/stance_image (3).jpeg
#   inflating: data/obj/__MACOSX/._stance_image (3).jpeg
#   inflating: data/obj/stance_image (3).txt
#   inflating: data/obj/stance_image (7).jpeg
#   inflating: data/obj/__MACOSX/._stance_image (7).jpeg
#   inflating: data/obj/stance_image (7).txt
#   inflating: data/obj/stance_image (8).jpeg
#   inflating: data/obj/__MACOSX/._stance_image (8).jpeg
#   inflating: data/obj/stance_image (8).txt
#   inflating: data/obj/stance_image (9).jpeg
#   inflating: data/obj/__MACOSX/._stance_image (9).jpeg
#   inflating: data/obj/stance_image (9).txt
#   inflating: data/obj/stance_image (10).jpeg
#   inflating: data/obj/__MACOSX/._stance_image (10).jpeg
#   inflating: data/obj/stance_image (10).txt
#   inflating: data/obj/stance_image (11).jpeg
#   inflating: data/obj/__MACOSX/._stance_image (11).jpeg
#   inflating: data/obj/stance_image (11).txt
#   inflating: data/obj/stance_image (14).jpeg
#   inflating: data/obj/__MACOSX/._stance_image (14).jpeg
#   inflating: data/obj/stance_image (14).txt
#   inflating: data/obj/stance_image (16).jpeg
#   inflating: data/obj/__MACOSX/._stance_image (16).jpeg
#   inflating: data/obj/stance_image (16).txt
#   inflating: data/obj/stance_image (17).jpeg
#   inflating: data/obj/__MACOSX/._stance_image (17).jpeg
#   inflating: data/obj/stance_image (17).txt
#   inflating: data/obj/stance_image (19).jpeg
#   inflating: data/obj/__MACOSX/._stance_image (19).jpeg
#   inflating: data/obj/stance_image (19).txt
#   inflating: data/obj/stance_image.jpeg
#   inflating: data/obj/__MACOSX/._stance_image.jpeg
#   inflating: data/obj/stance_image.txt
#   inflating: data/obj/stance_images (1).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (1).jpeg
#   inflating: data/obj/stance_images (1).txt
#   inflating: data/obj/stance_images (2).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (2).jpeg
#   inflating: data/obj/stance_images (2).txt
#   inflating: data/obj/stance_images (8).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (8).jpeg
#   inflating: data/obj/stance_images (8).txt
#   inflating: data/obj/stance_images (9).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (9).jpeg
#   inflating: data/obj/stance_images (9).txt
#   inflating: data/obj/stance_images (11).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (11).jpeg
#   inflating: data/obj/stance_images (11).txt
#   inflating: data/obj/stance_images (13).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (13).jpeg
#   inflating: data/obj/stance_images (13).txt
#   inflating: data/obj/stance_images (14).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (14).jpeg
#   inflating: data/obj/stance_images (14).txt
#   inflating: data/obj/stance_images (15).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (15).jpeg
#   inflating: data/obj/stance_images (15).txt
#   inflating: data/obj/stance_images (16).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (16).jpeg
#   inflating: data/obj/stance_images (16).txt
#   inflating: data/obj/stance_images (22).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (22).jpeg
#   inflating: data/obj/stance_images (22).txt
#   inflating: data/obj/stance_images (23).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (23).jpeg
#   inflating: data/obj/stance_images (23).txt
#   inflating: data/obj/stance_images (24).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (24).jpeg
#   inflating: data/obj/stance_images (24).txt
#   inflating: data/obj/stance_images (27).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (27).jpeg
#   inflating: data/obj/stance_images (27).txt
#   inflating: data/obj/stance_images (28).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (28).jpeg
#   inflating: data/obj/stance_images (28).txt
#   inflating: data/obj/stance_images (30).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (30).jpeg
#   inflating: data/obj/stance_images (30).txt
#   inflating: data/obj/stance_images (31).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (31).jpeg
#   inflating: data/obj/stance_images (31).txt
#   inflating: data/obj/stance_images (32).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (32).jpeg
#   inflating: data/obj/stance_images (32).txt
#   inflating: data/obj/stance_images (33).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (33).jpeg
#   inflating: data/obj/stance_images (33).txt
#   inflating: data/obj/stance_images (36).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (36).jpeg
#   inflating: data/obj/stance_images (36).txt
#   inflating: data/obj/stance_images (43).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (43).jpeg
#   inflating: data/obj/stance_images (43).txt
#   inflating: data/obj/stance_images (45).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (45).jpeg
#   inflating: data/obj/stance_images (45).txt
#   inflating: data/obj/stance_images (46).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (46).jpeg
#   inflating: data/obj/stance_images (46).txt
#   inflating: data/obj/stance_images (50).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (50).jpeg
#   inflating: data/obj/stance_images (50).txt
#   inflating: data/obj/stance_images (51).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (51).jpeg
#   inflating: data/obj/stance_images (51).txt
#   inflating: data/obj/stance_images (53).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (53).jpeg
#   inflating: data/obj/stance_images (53).txt
#   inflating: data/obj/stance_images (56).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (56).jpeg
#   inflating: data/obj/stance_images (56).txt
#   inflating: data/obj/stance_images (65).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (65).jpeg
#   inflating: data/obj/stance_images (65).txt
#   inflating: data/obj/stance_images (68).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (68).jpeg
#   inflating: data/obj/stance_images (68).txt
#   inflating: data/obj/stance_images (69).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (69).jpeg
#   inflating: data/obj/stance_images (69).txt
#   inflating: data/obj/stance_images (71).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (71).jpeg
#   inflating: data/obj/stance_images (71).txt
#   inflating: data/obj/stance_images (74).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (74).jpeg
#   inflating: data/obj/stance_images (74).txt
#   inflating: data/obj/stance_images (79).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (79).jpeg
#   inflating: data/obj/stance_images (79).txt
#   inflating: data/obj/stance_images (81).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (81).jpeg
#   inflating: data/obj/stance_images (81).txt
#   inflating: data/obj/stance_images (86).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (86).jpeg
#   inflating: data/obj/stance_images (86).txt
#   inflating: data/obj/stance_images (89).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (89).jpeg
#   inflating: data/obj/stance_images (89).txt
#   inflating: data/obj/stance_images (93).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (93).jpeg
#   inflating: data/obj/stance_images (93).txt
#   inflating: data/obj/stance_images (94).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (94).jpeg
#   inflating: data/obj/stance_images (94).txt
#   inflating: data/obj/stance_images (95).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (95).jpeg
#   inflating: data/obj/stance_images (95).txt
#   inflating: data/obj/stance_images (96).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (96).jpeg
#   inflating: data/obj/stance_images (96).txt
#   inflating: data/obj/stance_images (104).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (104).jpeg
#   inflating: data/obj/stance_images (104).txt
#   inflating: data/obj/stance_images (107).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (107).jpeg
#   inflating: data/obj/stance_images (107).txt
#   inflating: data/obj/stance_images (108).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (108).jpeg
#   inflating: data/obj/stance_images (108).txt
#   inflating: data/obj/stance_images (113).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (113).jpeg
#   inflating: data/obj/stance_images (113).txt
#   inflating: data/obj/stance_images (114).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (114).jpeg
#   inflating: data/obj/stance_images (114).txt
#   inflating: data/obj/stance_images (116).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (116).jpeg
#   inflating: data/obj/stance_images (116).txt
#   inflating: data/obj/stance_images (119).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (119).jpeg
#   inflating: data/obj/stance_images (119).txt
#   inflating: data/obj/stance_images (126).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (126).jpeg
#   inflating: data/obj/stance_images (126).txt
#   inflating: data/obj/stance_images (130).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (130).jpeg
#   inflating: data/obj/stance_images (130).txt
#   inflating: data/obj/stance_images (132).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (132).jpeg
#   inflating: data/obj/stance_images (132).txt
#   inflating: data/obj/stance_images (135).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (135).jpeg
#   inflating: data/obj/stance_images (135).txt
#   inflating: data/obj/stance_images (139).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (139).jpeg
#   inflating: data/obj/stance_images (139).txt
#   inflating: data/obj/stance_images (140).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (140).jpeg
#   inflating: data/obj/stance_images (140).txt
#   inflating: data/obj/stance_images (141).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (141).jpeg
#   inflating: data/obj/stance_images (141).txt
#   inflating: data/obj/stance_images (146).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (146).jpeg
#   inflating: data/obj/stance_images (146).txt
#   inflating: data/obj/stance_images (147).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (147).jpeg
#   inflating: data/obj/stance_images (147).txt
#   inflating: data/obj/stance_images (149).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (149).jpeg
#   inflating: data/obj/stance_images (149).txt
#   inflating: data/obj/stance_images (153).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (153).jpeg
#   inflating: data/obj/stance_images (153).txt
#   inflating: data/obj/stance_images (157).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (157).jpeg
#   inflating: data/obj/stance_images (157).txt
#   inflating: data/obj/stance_images (163).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (163).jpeg
#   inflating: data/obj/stance_images (163).txt
#   inflating: data/obj/stance_images (166).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (166).jpeg
#   inflating: data/obj/stance_images (166).txt
#   inflating: data/obj/stance_images (169).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (169).jpeg
#   inflating: data/obj/stance_images (169).txt
#   inflating: data/obj/stance_images (184).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (184).jpeg
#   inflating: data/obj/stance_images (184).txt
#   inflating: data/obj/stance_images (185).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (185).jpeg
#   inflating: data/obj/stance_images (185).txt
#   inflating: data/obj/stance_images (190).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (190).jpeg
#   inflating: data/obj/stance_images (190).txt
#   inflating: data/obj/stance_images (192).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (192).jpeg
#   inflating: data/obj/stance_images (192).txt
#   inflating: data/obj/stance_images (193).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (193).jpeg
#   inflating: data/obj/stance_images (193).txt
#   inflating: data/obj/stance_images (196).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (196).jpeg
#   inflating: data/obj/stance_images (196).txt
#   inflating: data/obj/stance_images (197).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (197).jpeg
#   inflating: data/obj/stance_images (197).txt
#   inflating: data/obj/stance_images (201).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (201).jpeg
#   inflating: data/obj/stance_images (201).txt
#   inflating: data/obj/stance_images (203).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (203).jpeg
#   inflating: data/obj/stance_images (203).txt
#   inflating: data/obj/stance_images (213).jpeg
#   inflating: data/obj/__MACOSX/._stance_images (213).jpeg
#   inflating: data/obj/stance_images (213).txt
#   inflating: data/obj/stance_images.png
#   inflating: data/obj/__MACOSX/._stance_images.png
#   inflating: data/obj/stance_images.txt
#   inflating: data/obj/stance_stance1.png
#   inflating: data/obj/__MACOSX/._stance_stance1.png
#   inflating: data/obj/stance_stance1.txt
#   inflating: data/obj/stance_stance2.png
#   inflating: data/obj/__MACOSX/._stance_stance2.png
#   inflating: data/obj/stance_stance2.txt
#   inflating: data/obj/stance_stance3.png
#   inflating: data/obj/__MACOSX/._stance_stance3.png
#   inflating: data/obj/stance_stance3.txt
#   inflating: data/obj/stance_stance4.png
#   inflating: data/obj/__MACOSX/._stance_stance4.png
#   inflating: data/obj/stance_stance4.txt
#   inflating: data/obj/stance_stance5.png
#   inflating: data/obj/__MACOSX/._stance_stance5.png
#   inflating: data/obj/stance_stance5.txt
#   inflating: data/obj/stance_stance6.png
#   inflating: data/obj/__MACOSX/._stance_stance6.png
#   inflating: data/obj/stance_stance6.txt
#   inflating: data/obj/stance_stance7.png
#   inflating: data/obj/__MACOSX/._stance_stance7.png
#   inflating: data/obj/stance_stance7.txt
#   inflating: data/obj/stance_stance8.png
#   inflating: data/obj/__MACOSX/._stance_stance8.png
#   inflating: data/obj/stance_stance8.txt
#   inflating: data/obj/stance_stance9.png
#   inflating: data/obj/__MACOSX/._stance_stance9.png
#   inflating: data/obj/stance_stance9.txt
#   inflating: data/obj/stance_stance10.png
#   inflating: data/obj/__MACOSX/._stance_stance10.png
#   inflating: data/obj/stance_stance10.txt
#   inflating: data/obj/stance_stance11.png
#   inflating: data/obj/__MACOSX/._stance_stance11.png
#   inflating: data/obj/stance_stance11.txt
#   inflating: data/obj/stance_stance12.png
#   inflating: data/obj/__MACOSX/._stance_stance12.png
#   inflating: data/obj/stance_stance12.txt
#   inflating: data/obj/stance_stance13.png
#   inflating: data/obj/__MACOSX/._stance_stance13.png
#   inflating: data/obj/stance_stance13.txt
#   inflating: data/obj/stance_stance14.png
#   inflating: data/obj/__MACOSX/._stance_stance14.png
#   inflating: data/obj/stance_stance14.txt
#   inflating: data/obj/stance_stance15.png
#   inflating: data/obj/__MACOSX/._stance_stance15.png
#   inflating: data/obj/stance_stance15.txt
#   inflating: data/obj/stance_stance16.png
#   inflating: data/obj/__MACOSX/._stance_stance16.png
#   inflating: data/obj/stance_stance16.txt

# %%
#this grabs just the filepaths of the pics in the folder with the labeled images and puts them in a list
import glob
images_list_jpg = glob.glob("data/obj/*.jpg")
images_list_jpeg = glob.glob("data/obj/*.jpeg")
images_list_png = glob.glob("data/obj/*.png")
print(len(images_list_jpg), images_list_jpg)
print()
print(len(images_list_jpeg), images_list_jpeg)
print()
print(len(images_list_png), images_list_png)
# Out:
# 171 ['data/obj/kick_sittichai-kicks-1024x576.jpg', 'data/obj/punch_Yokkao_41_Liam_Harrison_vs_Cristian_Faustino.jpg', 'data/obj/punch_images (1)6.jpg', 'data/obj/kick_muay-thai-techniques.jpg', 'data/obj/elbow_Ajh2eiURGqwdIi1hEhAp_file.jpg', 'data/obj/kick_220px-Roundhouse-kick.jpg', 'data/obj/elbow_944779295b12cf9d9eeac7cefdd0f5f8.jpg', 'data/obj/kick_3lowkickfeature-672x365.jpg', 'data/obj/kick_images (3).jpg', 'data/obj/punch_gettyimages-1159675648-1024x1024.jpg', 'data/obj/kick_s-l400.jpg', 'data/obj/punch_main-qimg-ee8742642fc61f73a1f8e6df920c983e.jpg', 'data/obj/kick_maxresdefault (8).jpg', 'data/obj/kick_hqdefault (3).jpg', 'data/obj/kick_Orono-Wor-Petchpun-1.jpg', 'data/obj/kick_maxresdefault (1).jpg', 'data/obj/elbow_buakaw-banchamek-gaetan-dambo.jpg', 'data/obj/kick_Muay-Thai-Moves-and-Techniques.jpg', 'data/obj/kick_103-aa-fp-mt-1.jpg', 'data/obj/elbow_main-qimg-9daca34bf95040196b059c7f512fa85f.jpg', 'data/obj/kick_maxresdefault (6).jpg', 'data/obj/elbow_main-qimg-2a8ccf2fab0809f3216afa833b2d75d6.jpg', 'data/obj/punch_buakaw_5.jpg', 'data/obj/kick_Muay-Thai-Kick-e1501527464581.jpg', 'data/obj/kick_unnamed.jpg', 'data/obj/punch_boxer-exercising-with-punch-bag-royalty-free-image-685043825-1565013219.jpg', 'data/obj/elbow_DOb544NXUAAJJG8.jpg', 'data/obj/kick_unnamed (6).jpg', 'data/obj/punch_images2.jpg', 'data/obj/elbow_21092_367408206680533_1199672835_n.jpg', 'data/obj/punch_images5.jpg', 'data/obj/kick_images (1).jpg', 'data/obj/punch_mg21128276.200-1_300.jpg', 'data/obj/punch_dcg1d4v-25ae1411-e62e-4c0b-9201-89d3e53b6377.
len(images_list)
# Out:
# 1156

# %%
#Opens training.txt file and puts in the filepaths we found above
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %% [markdown]
# # Start training

# %%
# Start the training. need to start from the beginning AGAIN bcs the .jpeg images were not being trained on. 
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show #(first run, using darknet weights and google colab pro)
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 19513, rewritten_bbox = 0.005125 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.162446), count: 4, total_loss = 6.806389
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.272281), count: 6, total_loss = 9.815663
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.097667
#  total_bbox = 19523, rewritten_bbox = 0.005122 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.516091), count: 4, total_loss = 3.056539
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.102579
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.097002
#  total_bbox = 19527, rewritten_bbox = 0.005121 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.373887), count: 5, total_loss = 6.341969
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.439804), count: 5, total_loss = 5.761310
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.097195
#  total_bbox = 19537, rewritten_bbox = 0.005118 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.310957), count: 4, total_loss = 4.919045
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.101675
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.094305
#  total_bbox = 19541, rewritten_bbox = 0.005117 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.377045), count: 4, total_loss = 4.646400
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.099434
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.099592
#  total_bbox = 19545, rewritten_bbox = 0.005116 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.466757), count: 3, total_loss = 2.834595
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.352848), count: 2, total_loss = 2.296132
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.098700
#  total_bbox = 19550, rewritten_bbox = 0.005115 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.318102), count: 4, total_loss = 5.748707
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.107499
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.094331
#  total_bbox = 19554, rewritten_bbox = 0.005114 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.445005), count: 4, total_loss = 3.789901
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.101874
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.100958
#  total_bbox = 19558, rewritten_bbox = 0.005113 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.495808), count: 5, total_loss = 4.648276
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.107365
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.099666
#  total_bbox = 19563, rewritten_bbox = 0.005112 %
#
#  258: 2.032094, 2.013072 avg loss, 0.000004 rate, 2.050929 seconds, 16512 images, 366.457970 hours left
# Loaded: 0.000062 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.315498), count: 4, total_loss = 7.230116
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.097528
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.090426
#  total_bbox = 19567, rewritten_bbox = 0.005111 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.536366), count: 4, total_loss = 4.208432
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.096630
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.092372
#  total_bbox = 19571, rewritten_bbox = 0.005110 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.505800), count: 4, total_loss = 3.464975
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.099708
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.097975
#  total_bbox = 19575, rewritten_bbox = 0.005109 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.394599), count: 5, total_loss = 4.925417
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.099478
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.096595
#  total_bbox = 19580, rewritten_bbox = 0.005107 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.621344), count: 4, total_loss = 3.785407
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.097872
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.096742
#  total_bbox = 19584, rewritten_bbox = 0.005106 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.471355), count: 4, total_loss = 3.665670
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.097394
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.093452
#  total_bbox = 19588, rewritten_bbox = 0.005105 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.300089), count: 5, total_loss = 6.055793
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 0.099018
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 0.090691
#  total_bbox = 19593, rewritten_bbox = 0.005104 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0